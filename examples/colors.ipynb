# %% [markdown]
# # Colors

# %% [markdown]
# This library uses the [Accessible Color Sequences for Data Visualization](https://doi.org/10.48550/arXiv.2107.02270) by Matthew A. Petroff.

# %%
import xplt

# %% [markdown]
# ## Colormaps

# %%
xplt.cmap_petroff

# %% [markdown]
# ---

# %%
xplt.cmap_petroff_gradient

# %% [markdown]
# ---

# %%
xplt.cmap_petroff_bipolar

# %% [markdown]
# ---

# %%
xplt.cmap_petroff_cyclic

# %% [markdown]
# ---

# %% [markdown]
# ## Usage

# %% [markdown]
# Colormaps are registered when importing xplt such that they can be used like `cmap='petroff_bipolar'`:

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
t = np.linspace(0, 2 * np.pi, 1024)
data2d = np.sin(t)[:, np.newaxis] * np.cos(t)[np.newaxis, :]
im = ax.imshow(data2d, cmap="petroff_bipolar")
fig.colorbar(im, ax=ax, label="Color");

# %% [markdown]
# ------------
# ```{seealso}
# - {class}`xplt.colors`
# ```
