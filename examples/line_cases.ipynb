# %%
# %matplotlib widget

# %%
import numpy as np
import xtrack as xt

# %%
env = xt.Environment()

# %%
l1 = env.new_line(components=[
    env.new('mb1', 'Bend', angle=np.pi/4, length=1, at=5),
    env.new('mb2', 'Bend', angle=-np.pi/4, length=1, at=10),
    env.new('end', 'Marker', at=15)
])

# %%
l1.survey().plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
l2 = env.new_line(components=[
    env.new('m1', 'Multipole', knl=[np.pi/4], hxl=np.pi/4, length=1, at=5),
    env.new('m2', 'Multipole', knl=[-np.pi/4], hxl=-np.pi/4, length=1, at=10),
    env.new('ee', 'Marker', at=15)
])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 l2 = env.new_line(components=[
# ----> 2     env.new('m1', 'Multipole', knl=[np.pi/4], hxl=[np.pi/4], length=1, at=5),
#       3     env.new('m2', 'Multipole', knl=[-np.pi/4], hxl=[-np.pi/4], length=1, at=10),
#       4     env.new('ee', 'Marker', at=15)
#       5 ])
#
# File ~/xsuite_packages/xtrack/xtrack/environment.py:209, in Environment.new(self, name, parent, mode, at, from_, anchor, from_anchor, extra, mirror, force, import_from, **kwargs)
#     207     all_kwargs.pop('kwargs')
#     208     all_kwargs.update(kwargs)
# --> 209     return Place(self.new(**all_kwargs), at=at, from_=from_,
#     210                  anchor=anchor, from_anchor=from_anchor)
#     212 _ALLOWED_ELEMENT_TYPES_IN_NEW = xt.line._ALLOWED_ELEMENT_TYPES_IN_NEW
#     213 _ALLOWED_ELEMENT_TYPES_DICT = xt.line._ALLOWED_ELEMENT_TYPES_DICT
#
# File ~/xsuite_packages/xtrack/xtrack/environment.py:279, in Environment.new(self, name, parent, mode, at, from_, anchor, from_anchor, extra, mirror, force, import_from, **kwargs)
#     276 if needs_instantiation: # Parent is a class and not another element
#     277     self.element_dict[name] = parent(**value_kwargs)
# --> 279 _set_kwargs(name=name, ref_kwargs=ref_kwargs, value_kwargs=value_kwargs,
#     280             element_dict=self.element_dict, element_refs=self.element_refs)
#     282 if extra is not None:
#     283     assert isinstance(extra, dict)
#
# File ~/xsuite_packages/xtrack/xtrack/environment.py:1112, in _set_kwargs(name, ref_kwargs, value_kwargs, element_dict, element_refs)
#    1110 if hasattr(value_kwargs[kk], '__iter__') and not isinstance(value_kwargs[kk], str):
#    1111     len_value = len(value_kwargs[kk])
# -> 1112     getattr(element_dict[name], kk)[:len_value] = value_kwargs[kk]
#    1113     if kk in ref_kwargs:
#    1114         for ii, vvv in enumerate(value_kwargs[kk]):
#
# TypeError: 'numpy.float64' object does not support item assignment

# %%
l2.survey().plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 l2.survey().plot()
#
# NameError: name 'l2' is not defined
